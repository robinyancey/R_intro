# %% [markdown]
# <!-- # Week 4: Coding Exercises
# ### Total: 100 Points
# - 5 Coding Exercises (15 points each)
# - 5 Multiple Choice Questions (2 points each)
# - 5 Fill in the Blank Questions (3 points each) -->

# %% [markdown]
# ## Part 1: Coding Exercises

# %% [markdown]
# # Exercise 1
# ### **Write then read a CSV with a custom separator and inspect it**
# 1. Create a data frame with empID, employee name, Date of Registration, Gender, Occupation, Age and Salary
#
# 2. Write it to a CSV file using semicolon (;) as the separator.
#
# 3. Read the file back and show the structure of the data.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2
# ### Read an Excel sheet and check for missing values:
# 1. Read "data" sheet from "employee_data.xlsx" (provided in resource folder)
# 2. Count the number of missing values in each column.
# 3. Find mean salary
# 4. Find the highest and lowest paid employee.
# 5. Add column Age and calculate the current employee ages.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3
# ### Use transform() and within() to modify dataset:
#
# 1. Use transform() to add a new column called "employee_age". Get how long the employee has been in the business, using current year and "date of regestration" column.
#
# 2. Use within() to update the Age column by adding 1 to all values

# %%
# Your code here

# %% [markdown]
# ## Exercise 4
# ### Create a subset and calculate summary stats
#
# 1. Filter a dataset to only include rows where salary > 15000.
#
# 2. Calculate the mean and standard deviation of Age in this subset.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5
# ### Apply statistical functions to multiple numeric columns in a dataset:
# You are given a data frame with multiple numeric columns (e.g., math, science, history scores).
#
# 1. Create a dataset with at least 5 student names and scores in 3 subjects: Math, Science, History.
#
#   - Use `sapply()` to calculate the mean score per subject.
#
#   - Use `lapply()` to determine whether each subject has any score below 50 (i.e., a fail) and return logical values.
#
# 2. Print both result

# %%
# Your code here

# %% [markdown]
# ## Part 2: Multiple Choice Questions

# %% [markdown]
# 1. Which function is used to read a CSV file in R?
# * A. read_excel()
# * B. read_file()
# * C. read.csv()
# * D. open.csv()

# %% [markdown]
# 2. What does `merge(df1, df2)` do by default?
# - A. Combines by row
# - B. Merges on all common columns
# - C. Only keeps unique rows
# - D. Deletes duplicate rows

# %% [markdown]
# 3. Which package is commonly used for data manipulation?
# - A. plotly
# - B. dplyr
# - C. shiny
# - D. lubridate

# %% [markdown]
# 4. What does `write.csv(df, 'file.csv')` do?
# - A. Reads a CSV
# - B. Merges files
# - C. Writes a data frame to CSV
# - D. Deletes a file

# %% [markdown]
# 5. What will `na.omit(df)` do?
# - A. Fills NA with 0
# - B. Removes NA rows
# - C. Adds NA
# - D. None of the above

# %% [markdown]
# ## Fill in the Blank

# %% [markdown]
# 1. To read Excel files in R, we use the _______ package.

# %% [markdown]
# 2. The function used to inspect the structure of a data frame is _______.
