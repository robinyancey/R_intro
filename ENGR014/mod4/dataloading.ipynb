# %% [markdown]
# ## 📁 Data Loading Instructions for Google Colab
#
# **If you're running this notebook on Google Colab, follow these steps to load the required datasets:**
#
# ### Option 1: Upload Files Directly
# 1. Click the **Files** tab in the left sidebar (📁 icon)
# 2. Click **Upload** and select the following files from your local machine.
# 3. The files will be uploaded to the `/content/` directory
# 4. **No code changes needed** - the notebook will automatically find the files
#
# ### Option 2: Mount Google Drive
# If your data files are stored in Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')

# Then update the file paths in the notebook to point to your Drive location:
# Example: 'drive/MyDrive/data/prgeng.csv'

# %% [markdown]
# ### Option 3: Download from URL
# If your datasets are available online:

# %%
import pandas as pd

# Example: Download directly from a URL
url = "https://your-dataset-url.com/prgeng.csv"
wage_data = pd.read_csv(url)

# %% [markdown]
# ### ⚠️ Important Notes:
# - File uploads in Colab are **temporary** and will be lost when the runtime disconnects
# - For persistent storage, use Google Drive (Option 2)
# - Make sure file paths in the code match where you've stored your data
#
# ---
