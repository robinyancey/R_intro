# %% [markdown]
# ## **Week 5: Data Visualization with Real-World Datasets**
#
# ---
#
# ###  **Part A: Exercises (5 Tasks)**
#
# #### **Exercise 1: Histogram  COVID-19 Daily Case Trends**
#
# * **Task:** Download the [NYT COVID-19 dataset by county](https://github.com/nytimes/covid-19-data).
# * **Objective:** Using the `cases` column, create **separate histograms** of daily new cases in two states of your choice.
# * **Stretch:** Interpret the spread and skewness — which state had more volatile case reporting?
#
# #### **Exercise 2: Parallel Boxplot - Compare COVID-19 Case Totals**
#
# * **Task:** Using the same dataset, group data by **state**, and use a parallel boxplot to show the **distribution of total cases per county** in each state.
# * **Hint:** Use `dplyr` to group and `ggplot2::geom_boxplot()` for visualization.
# * **Interpretation:** Which state shows the most variation in county case totals?
#
# #### **Exercise 3: 3D Plot - Visualize COVID-19 Deaths Geographically**
#
# * **Task:** Generate a 3D scatter plot using **longitude, latitude, and total deaths** across all U.S. counties.
# * **Hint:** Use the `plotly` or `scatterplot3d` package.
# * **Insight:** Which regions appear to have the highest mortality clusters?
#
# #### **Exercise 4: Bar Chart - States with Highest Average Admission Rates**
#
# * **Task:** From the [College Scorecard dataset](https://collegescorecard.ed.gov/data/), calculate the **average admission rate per state** and plot the **top 5 states**.
# * **Hint:** use `Most-Recent-Cohorts-Institution.csv` dataset
# * **Bonus:** Add value labels above each bar.
#
# #### **Exercise 5: Pie Chart - CS & Engineering Degree Distribution**
#
# * **Task:** Filter the dataset for **Computer Science and Engineering** programs. Create a **pie chart** showing the **proportion of different degree levels** (Associate, Bachelor, Master, Doctoral).
# * **Goal:** Understand how education levels vary across tech fields.
#
# ---
#
# ### **Part B: Multiple Choice Questions (5)**
#
# > *Choose the correct option from the choices provided.*
#
# 1. **Which R function is most appropriate for drawing a 3D plot with three numeric variables?**
#    * A. `geom_point3d()`
#    * B. `plot3d()`
#    * C. `scatterplot3d()`
#    * D. `plotly3d()`
#
# 2. **What aspect of a boxplot shows the interquartile range (IQR)?**
#    * A. The whiskers
#    * B. The box edges
#    * C. The outliers
#    * D. The median line
#
# 3. **Which R function can convert a categorical variable into a factor for coloring?**
#    * A. `as.character()`
#    * B. `recode()`
#    * C. `as.factor()`
#    * D. `mutate()`
#
# 4. **What ggplot function is used to add a histogram to a plot?**
#    * A. `geom_bar()`
#    * B. `geom_line()`
#    * C. `geom_histogram()`
#    * D. `geom_boxplot()`
#
# 5. **Which state had the most variability in county-level COVID-19 case counts? (based on your boxplot)**
#   * A. New York
#   * B. Texas
#   * C. California
#   * D. Your analysis result
#
# ---
#
# ### **Part C: Fill-in-the-Blank (2 Questions)**
#
# > *Complete the sentences below.*
#
# 1. A histogram is used to display the \_\_\_\_\_\_\_\_ of a numeric variable by binning it into intervals.
#
# 2. To convert latitude and longitude into a usable 3D scatter plot, we use them as the \_\_\_\_\_\_\_\_ and \_\_\_\_\_\_\_\_ axes.
