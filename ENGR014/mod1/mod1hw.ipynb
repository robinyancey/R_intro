# %% [markdown]
# ## Coding Exercises (Week 1 -> Part One)
#
# ---
#
# ### **Exercise 1: Basic Vector Statistics**
#
# Create a numeric vector named `scores` with the following values:
# `75, 80, 82, 90, 70`
#
# 1. Calculate the **mean** of `scores`.
# 2. What is the **standard deviation**?
# 3. What is the **maximum** value?
#
# > *You must assign the results to:*
#
# * `mean_score`
# * `sd_score`
# * `max_score`

# %%
# code here

# %% [markdown]
# ### **Exercise 2: Matrix Operations**
#
# Create a 2x3 matrix using numbers 1 to 6, filled **by row**.
# Assign it to a variable called `mat`.
#
# 1. Extract the value in the **second row, third column** and assign to `value_23`
# 2. Transpose the matrix and assign it to `mat_trans`
# 3. Calculate the **sum of row 1** in `mat` and store it in `row1_sum`

# %%
# code here

# %% [markdown]
# ### **Exercise 3: Array Inspection**
#
# Create a **2x2x2** array using values `1:8`. Assign it to `arr`.
#
# 1. Print the full array
# 2. Extract the value at position `[2, 1, 2]` and assign it to `target_val`
# 3. What is the **sum of all values** in the array? Assign it to `arr_sum`

# %%
#code here

# %% [markdown]
# ## Exercise 4: Use of Built-in Mathematical Functions
# #### Perform the following calculations using R's built-in mathematical functions:
#
# #### 1. Assign the value of pi to a variable called `my_pi`
# #### 2. Calculate the square root of 64
# #### 3. Find the logarithm (natural log) of 10
# #### 4. Round the number 3.14159 to 3 decimal places
# #### 5. Use the exp() function to calculate e^2

# %%
#code here
# Out:
# [1] 3.141593

# %% [markdown]
# ## Exercise 5: Summary Statistics from a Data Sample
# #### You are given a set of temperature readings in degrees Celsius, please caluclate the summary of the stats on this vector.

# %%
temperatures <- c(23.4, 21.8, 24.6, 22.0, 20.9, 25.5, 23.0)

# code here

# %% [markdown]
# ---
#
# ## 📋 Assessment Questions (Part Two)
#
#
# 1. **Which function in R calculates the mean of a numeric vector?**
#
#    * A) `sum()`
#    * B) `mean()`
#    * C) `median()`
#    * D) `average()`
#
# 2. **What is the output of the following R code?**
#
#    ```r
#    x <- c(2, 4, 6)
#    x[2]
#    ```
#
#    * A) 2
#    * B) 4
#    * C) 6
#    * D) Error
#
# 3. **Which function is used to create a matrix in R?**
#
#    * A) `array()`
#    * B) `matrix()`
#    * C) `mat()`
#    * D) `data.frame()`
#
# 4. **What does the `length()` function return when applied to a vector?**
#
#    * A) The sum of elements
#    * B) The number of elements
#    * C) The maximum value
#    * D) The minimum value
#
# 5. **In R, which operator is used for matrix multiplication?**
#
#    * A) `*`
#    * B) `%*%`
#    * C) `%%`
#    * D) `^`
#
# ### **Fill-in-the-Blank Questions**
#
# 6. **Fill in the blank:** In R, the function `________()` returns the standard deviation of a numeric vector.
#
# 7. **Fill in the blank:** To create a vector containing the numbers 1 through 5 in R, you can use the syntax `________`.
