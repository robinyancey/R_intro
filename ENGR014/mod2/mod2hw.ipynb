# %% [markdown]
# #  Student Coding Exercises (Week 2: Topics 2.0 to 2.6)
# ### Instructions:
# Write your code in the cells provided. Comments (starting with `#`) are where you should add answers or notes.

# %% [markdown]
# ### **Exercise 1 - Matrix Multiplication (Topic 2.0)**
# Create two matrices:
# - Matrix A: 2x3
# - Matrix B: 3x2
#
# Then multiply them and print the resulting matrix.

# %%
#code here

# %% [markdown]
# ### **Exercise 2 - Handling NA and NULL (Topic 2.1)**
# Given the following vector:
#
# ```r
# x <- c(4, NA, 7, NULL, 3, NA)
# ```
# Write code to:
# 1. Remove all `NA` values
# 2. Calculate the mean of the cleaned vector

# %%
#code here

# %% [markdown]
# ### **Exercise 3 – Create a List and Access Elements (Topic 2.2)**
# Create a list named `person` with:
# - Name = "Alice"
# - Age = 25
# - Grades = c(88, 92, 95)
#
# Then extract the second grade (92) and assign it to a variable called `second_grade`.

# %%
#code here

# %% [markdown]
# ### **Exercise 4 – Identify Class and Convert Type (Topic 2.3)**
# Given:
# ```r
# num <- "42"
# ```
# 1. Check the class of `num`
# 2. Convert it into a numeric type
# 3. Multiply the result by 2

# %%
#code here

# %% [markdown]
# ### **Exercise 5 – Probability: Normal Distribution (Topic 2.6)**
# Calculate the probability that a value from a normal distribution with mean 70 and sd 10 is less than 80.

# %%
#code here

# %% [markdown]
# # **Multiple Choice Questions**
#
# **1. What is the result of multiplying a 2x3 matrix with a 3x2 matrix in R?**
# - A. Error - dimensions don't match
# - B. A 2x2 matrix
# - C. A 3x3 matrix
# - D. A 2x3 matrix
#
#
# **2. Which of the following is the correct way to create a list with named elements in R?**
# - A. `list("Name", "John", "Age", 25)`
# - B. `c(Name = "John", Age = 25)`
# - C. `list(Name = "John", Age = 25)`
# - D. `list["Name" = "John", "Age" = 25]`
#
#
# **3. The function used to generate a normal distribution in R is:**
# - A. `dnorm()`
# - B. `pnorm()`
# - C. `rnorm()`
# - D. All of the above
#
# ---
#
# **4. Which of the following will correctly return the class of a variable `x`?**
# - A. `typeof(x)`
# - B. `mode(x)`
# - C. `class(x)`
# - D. `is.class(x)`
#
#
#
# # **Fill in the Blank**
#
# **5. In R, a matrix is a \_\_\_\_\_\_\_\_\_\_\_ array of elements of the same basic type.**
#
#
#
#
#
# **6. A \_\_\_\_\_\_\_\_\_\_\_ in R can contain elements of different types like numbers, strings, and even other lists.**
#
#
# **7. The probability that a random variable from a normal distribution is less than a given value is computed using the \_\_\_\_\_\_\_\_\_\_\_ function.**
